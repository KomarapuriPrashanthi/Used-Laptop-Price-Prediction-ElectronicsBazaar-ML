# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab import drive

# 📂 Mount Google Drive
drive.mount('/content/drive')

# 📥 Load the Cleaned Laptop Dataset
csv_path = "/content/drive/MyDrive/MLOPs Project(Laptops)/EB_laptops_data_cleaned.csv"
print(f"\n📂 Loading data from: {csv_path}")
df = pd.read_csv(csv_path)

# 🖼️ Preview the Data
print("\n🔹 First 5 rows of the dataset:")
print(df.head())

# 1️⃣ BASIC DATA OVERVIEW
print("\n🔎 Dataset Info:")
print(df.info())

print("\n📏 Dataset Shape:")
print(f"Rows: {df.shape[0]}, Columns: {df.shape[1]}")

print("\n🧮 Descriptive Statistics (Numerical Columns):")
print(df.describe())

print("\n📊 Descriptive Statistics (Categorical Columns):")
print(df.describe(include='object'))

# 2️⃣ MISSING VALUES & DUPLICATES
print("\n❓ Missing Values Per Column:")
print(df.isnull().sum())

print("\n🧹 Checking for Duplicates:")
duplicates = df.duplicated().sum()
print(f"🔁 Number of duplicate rows: {duplicates}")

# 3️⃣ COLUMN-WISE UNIQUE VALUES
print("\n🔍 Unique Values per Column:")
for col in df.columns:
    print(f"{col}: {df[col].nunique()} unique values")

# 4️⃣ CORRELATION HEATMAP
print("\n🔗 Correlation Heatmap (Numerical Columns Only):")
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()

print("\n✅ EDA Complete.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# 📂 Loading data from: /content/drive/MyDrive/MLOPs Project(Laptops)/EB_laptops_data_cleaned.csv
#
# 🔹 First 5 rows of the dataset:
#     Brand              Processor  RAM(GB)  Storage(GB)  Screen Size(inch)  \
# 0  Lenovo       Core i5 10th Gen        8          512               35.5
# 1  Lenovo       Core i5 12th Gen       16          512               35.5
# 2      HP  AMD APU Quad Core A12        4         1024               39.6
# 3      HP        Core i5 7th Gen        8          512               39.6
# 4      HP                    NaN        4           64               29.4
#
#      Condition                                           Warranty  Price
# 0  Refurbished  1 Year Warranty. Battery & Adapter - 6 Months ...  38400
# 1  Refurbished  1 Year Warranty. Battery & Adapter - 6 Months ...  54900
# 2  Refurbished  1 Year Warranty. Battery & Adapter - 6 Months ...  33400
# 3  Refurbished  1 Year Warranty. Battery & Adapter - 6 Months ...  25800
# 4  Refurbished  1 Year Warranty. Battery & Adapter - 6 Months ...  16500
#
# 🔎 Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Brand              145 non-null    object
#  1   Processor          143 non-null    object
#  2   RAM(GB)            145 non-null    int64
#  3   Storage(GB)        145 non-null    int64
#  4   Screen Size(inch)  145 non-null    float64
#  5   Condition          145 non-null    object
#  6   Warranty           145 non-null    object
#  7   Price              145 non-null    int64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 9.2+ KB
# None
#
# 📏 Dataset Shape:
# Rows: 145, Columns: 8
#
# 🧮 Descriptive Statistics (Numerical Columns):
#           RAM(GB)  Storage(GB)  Screen Size(inch)          Price
# count  145.000000   145.000000         145.000000     145.000000
# mean    13.820690   699.503448          38.386207   65821.434483
# std      5.925075   293.500287           2.745315   30866.988277
# min      4.000000    64.000000          29.400000   14400.000000
# 25%      8.000000   512.000000          35.500000   43400.000000
# 50%     16.000000   512.000000          39.600000   61600.000000
# 75%     16.000000  1024.000000          40.600000   82001.000000
# max     32.000000  2048.000000          43.900000  207600.000000
#
# 📊 Descriptive Statistics (Categorical Columns):
#        Brand         Processor    Condition  \
# count    145               143          145
# unique     3                27            1
# top       HP  Core i7 13th Gen  Refurbished
# freq     122                22          145
#
#                                                  Warranty
# count                                                 145
# unique                                                  1
# top     1 Year Warranty. Battery & Adapter - 6 Months ...
# freq                                                  145
#
# ❓ Missing Values Per Column:
# Brand                0
# Processor            2
# RAM(GB)              0
# Storage(GB)          0
# Screen Size(inch)    0
# Condition            0
# Warranty             0
# Price                0
# dtype: int64
#
# 🧹 Checking for Duplicates:
# 🔁 Number of duplicate rows: 0
#
# 🔍 Unique Values per Column:
# Brand: 3 unique values
# Processor: 27 unique values
# RAM(GB): 4 unique values
# Storage(GB): 6 unique values
# Screen Size(inch): 8 unique values
# Condition: 1 unique values
# Warranty: 1 unique values
# Price: 128 unique values
#
# 🔗 Correlation Heatmap (Numerical Columns Only):
# ✅ EDA Complete.
